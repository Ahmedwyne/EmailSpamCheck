# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmedwyne/EmailSpamCheck/blob/main/emailSpam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv('/content/spam_ham_dataset.csv')

# %%
df
# Out:
#       Unnamed: 0 label                                               text  \
# 0            605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1           2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2           3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3           4685  spam  Subject: photoshop , windows , office . cheap ...
# 4           2030   ham  Subject: re : indian springs\r\nthis deal is t...
# ...          ...   ...                                                ...
# 5166        1518   ham  Subject: put the 10 on the ft\r\nthe transport...
# 5167         404   ham  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168        2933   ham  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169        1409   ham  Subject: industrial worksheets for august 2000...
# 5170        4807  spam  Subject: important online banking alert\r\ndea...
#
#       label_num
# 0             0
# 1             0
# 2             0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 label                                               text  \
# 0         605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685  spam  Subject: photoshop , windows , office . cheap ...
# 4        2030   ham  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
df['text'] = df['text'].apply(lambda x: x.replace('\r\n', ' '))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5171 entries, 0 to 5170
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5171 non-null   int64
#  1   label       5171 non-null   object
#  2   text        5171 non-null   object
#  3   label_num   5171 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 161.7+ KB

# %%
stemmer = PorterStemmer()
corpus = []

stopwords_set = set(stopwords.words('english'))

for i in range(len(df)):
  text = df['text'].iloc[i].lower()
  text = text.translate(str.maketrans('','' , string.punctuation)).split()
  text = [stemmer.stem(word) for word in text if word not in stopwords_set]
  text = ' '.join(text)
  corpus.append(text)

# %%
vectorizer = CountVectorizer()

X = vectorizer.fit_transform(corpus).toarray()
y = df.label_num

X_train , X_test , y_train , y_test = train_test_split(X,y , test_size=0.2)

# %%
clf = RandomForestClassifier()

clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
clf.score(X_test , y_test)
# Out:
# 0.970048309178744

# %% [markdown]
# # Testing the model results

# %%
# email_to_classify = df.text.values[120]

# %%
# email_to_classify

# %%
# email_text = email_to_classify.lower().translate(str.maketrans('', '',string.punctuation)).split()
# email_text = [stemmer.stem(word) for word in text if word not in stopwords_set]
# email_text = ' '.join(email_text)

# email_corpus = [email_text]

# X_email = vectorizer.transform(email_corpus)

# %%
# clf.predict(X_email)

# %%
# df.label_num.iloc[120]

# %%
# df['label_num'].iloc[120]

# %%
# import pickle

# model = RandomForestClassifier
# # Save the trained model to a file
# with open('C:\\Users\\DeadUser\\Desktop\\Internship task\\Email Spam DataSet\\random_forest_model.pkl', 'wb') as file:
#     pickle.dump(model, file)

import pickle

model = CountVectorizer
# Save the trained model to a file
with open('CountVectorizer.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
# from google.colab import files

# # Download the file
# files.download('CountVectorizer.pkl')


# from google.colab import files

# # Download the file
# files.download('RandomForestClassifier.pkl')

# %%
# Out:
# <bound method IndexOpsMixin.value_counts of 0        ham
# 1        ham
# 2        ham
# 3       spam
# 4        ham
#         ...
# 5166     ham
# 5167     ham
# 5168     ham
# 5169     ham
# 5170    spam
# Name: label, Length: 5171, dtype: object>
